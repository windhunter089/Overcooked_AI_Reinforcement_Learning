# %%
### Install libraries ###

# !pip install git+https://github.com/HumanCompatibleAI/overcooked_ai.git

# %%
"""
Project3 Overcooked AI
tdpham328
"""


### Imports ###

from overcooked_ai_py.mdp.overcooked_mdp import OvercookedGridworld
from overcooked_ai_py.mdp.overcooked_env import OvercookedEnv
from overcooked_ai_py.agents.agent import NNPolicy, AgentFromPolicy, AgentPair
from overcooked_ai_py.agents.benchmarking import AgentEvaluator
from overcooked_ai_py.visualization.state_visualizer import StateVisualizer
import gym
import numpy as np
import matplotlib.pyplot as plt

import torch as T
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

from PIL import Image
import os
from IPython.display import display, Image as IPImage

## Uncomment if you'd like to use your personal Google Drive to store outputs
## from your runs. You can find some hooks to Google Drive commented
## throughout the rest of this code.
# from google.colab import drive

class DQN(nn.Module):
    def __init__(self, alpha, state_dim, action_dim, hidden_dims):
        super(DQN, self).__init__()
        self.state_dim = state_dim
        self.action_dim = action_dim
        self.hidden_dims = hidden_dims

        self.fc1 = nn.Linear(*self.state_dim, self.hidden_dims[0])
        # self.fc1_bn = nn.BatchNorm1d(self.hidden_dims[0])
        # self.fc1_ln = nn.LayerNorm(self.hidden_dims[0])
        self.fc2 = nn.Linear(self.hidden_dims[0], self.hidden_dims[1])
        # self.fc2_ln = nn.LayerNorm(self.hidden_dims[1])
        # self.fc2_bn = nn.BatchNorm1d(self.hidden_dims[1])
        self.fc3 = nn.Linear(self.hidden_dims[1], self.action_dim)
        # self.dropout = nn.Dropout(p = 0.1)
        self.double()
        # self.float()

        self.optimizer = optim.Adam(self.parameters(), lr = alpha)
        self.loss = nn.SmoothL1Loss()
        # self.device = T.device('cuda:0' if T.cuda.is_available() else 'cpu')
        self.device = T.device('cpu')
        self.to(self.device)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        # x = F.relu(self.fc1_ln(self.fc1(x)))
        # x = self.dropout(x)
        x = F.relu(self.fc2(x))
        # x = F.relu(self.fc2_ln(self.fc2(x)))
        return self.fc3(x)

# Define Replay Buffer
class ReplayBuffer():
    def __init__(self, state_dim, action_dim, max_mem_size):
        self.max_mem_size = max_mem_size
        self.state_dim = state_dim
        self.action_dim = action_dim
        self.a0_state_memory = np.zeros((max_mem_size, *state_dim), dtype = np.float64)
        self.a1_state_memory = np.zeros((max_mem_size, *state_dim), dtype = np.float64)
        self.a0_action_memory = np.zeros(max_mem_size, dtype = np.int32)
        self.a1_action_memory = np.zeros(max_mem_size, dtype = np.int32)
        self.a0_new_state_memory = np.zeros((max_mem_size, *state_dim), dtype = np.float64)
        self.a1_new_state_memory = np.zeros((max_mem_size, *state_dim), dtype = np.float64)
        self.reward_memory = np.zeros(max_mem_size, dtype = np.float32)
        self.terminal_memory = np.zeros(max_mem_size, dtype = np.bool_)
        self.mem_counter = 0


# Define the agent
class Agent():
    def __init__(self, gamma, epsilon, alpha, state_dim, action_dim,
                 eps_min, eps_decay):
        self.gamma = gamma
        self.epsilon = epsilon
        self.alpha = alpha
        self.eps_min = eps_min
        self.eps_decay = eps_decay
        self.action_list = [i for i in range(action_dim)]

        # Q-network
        # Set up 2 different Q-network for online network and target network
        self.Q_network = DQN(self.alpha, action_dim = action_dim, state_dim= state_dim, hidden_dims = [128,128])
        self.Q_target = DQN(self.alpha, action_dim = action_dim, state_dim= state_dim, hidden_dims = [128,128])
        self.Q_target.load_state_dict(self.Q_network.state_dict())

        # # Set up a buffer to store the experience (current state, action, reward, new state, terminal state)
        # self.state_memory = np.zeros((self.max_mem_size, *state_dim), dtype = np.float64)
        # self.action_memory = np.zeros(self.max_mem_size, dtype = np.int32)
        # self.new_state_memory = np.zeros((self.max_mem_size, *state_dim), dtype = np.float64)
        # self.reward_memory = np.zeros(self.max_mem_size, dtype = np.float32)
        # self.terminal_memory = np.zeros(self.max_mem_size, dtype = np.bool_)

    def ChooseAction(self,observation):
        # random chance of exploration phase
        if np.random.random() <= self.epsilon:
            return np.random.choice(self.action_list)
        # greedy pick
        else:
            state = T.tensor([observation]).to(self.Q_network.device)
            return T.argmax(self.Q_network.forward(state)).item()

    # function to update the Q target network
    def update_target_network(self):
        self.Q_target.load_state_dict(self.Q_network.state_dict())
    # SOFT UPDATE TARGET NETWORK
    def soft_update_target_network(self, tau = 0.001):
        for target_param, local_param in zip(self.Q_target.parameters(), self.Q_network.parameters()):
            target_param.data.copy_(tau * local_param.data + (1.0 - tau) * target_param.data)

if __name__ == '__main__':

    ### Environment setup ###

    ## Swap between the 5 layouts here:

    # layout = "cramped_room"
    layout = "asymmetric_advantages"
    # layout = "coordination_ring"
    # layout = "forced_coordination"
    # layout = "counter_circuit_o_1order"

    ## Reward shaping is disabled by default; i.e., only the sparse rewards are
    ## included in the reward returned by the enviornment).  If you'd like to do
    ## reward shaping (recommended to make the task much easier to solve), this
    ## data structure provides access to a built-in reward-shaping mechanism within
    ## the Overcooked environment.  You can, of course, do your own reward shaping
    ## in lieu of, or in addition to, using this structure. The shaped rewards
    ## provided by this structure will appear in a different place (see below)
    reward_shaping = {
        "PLACEMENT_IN_POT_REW": 1,
        "DISH_PICKUP_REWARD": 3,
        "SOUP_PICKUP_REWARD": 5
    }

    # Length of Episodes.  Do not modify for your submission!
    # Modification will result in a grading penalty!
    horizon = 400

    # Build the environment.  Do not modify!
    mdp = OvercookedGridworld.from_layout_name(layout, rew_shaping_params=reward_shaping)
    base_env = OvercookedEnv.from_mdp(mdp, horizon=horizon, info_level=0)
    env = gym.make("Overcooked-v0", base_env=base_env, featurize_fn=base_env.featurize_state_mdp)

    # SET UP AGENT
    agent0 = Agent(gamma = 0.9, epsilon = 1.00, alpha = 0.0003, state_dim=[96],
                  action_dim = 6, eps_min= 0.15, eps_decay=0.00001)
    agent1 = Agent(gamma = 0.9, epsilon = 1.00, alpha = 0.0003, state_dim=[96],
                  action_dim = 6, eps_min= 0.15, eps_decay=0.00001)
    buffer = ReplayBuffer(state_dim=[96],action_dim = 6, max_mem_size= 100000)
    buffer.mem_counter = 0
    batch_size = 1024

    ### Train your agent ###
    # The code below runs a few episodes with a random agent.  Your learning algorithm
    # would go here.
    soup_final = []
    dish_pickup = []
    potting_onion = []
    soup_SMA100 = []
    num_episodes = 1000

    for e in range(num_episodes):
        # Episode termination flag
        terminal = False
        # The number of soups the agent pair made during the episode
        num_soups_made = 0
        # Reset the environment at the start of each episode
        obs = env.reset()
        combined_reward = 0
        total_reward = 0
        r_0 = 0
        r_1 = 0
        upd_target_counter = 0

        while not terminal:
            # set pointer to go back overwrite oldest mem if full
            pointer = buffer.mem_counter % buffer.max_mem_size

            # Obtain observations for each agent
            if env.agent_idx:
                obs0 = obs["both_agent_obs"][1]
                obs1 = obs["both_agent_obs"][0]
            else:
                obs0 = obs["both_agent_obs"][0]
                obs1 = obs["both_agent_obs"][1]

            # EXPERIENCE/STEP
            a0 = agent0.ChooseAction(obs0)
            a1 = agent1.ChooseAction(obs1)
            if env.agent_idx:
                obs, R, terminal, info = env.step([a1,a0])
            else:
                obs, R, terminal, info = env.step([a0,a1])

            # You can find the separate shaping rewards induced by the data
            # structure you defined above in the "info" dictionary.
            ## THE REVERSAL OF THIS ARRAY IS NECESSARY TO ALIGN THE CORRECT REWARD
            ## TO THE CORRECT AGENT (see project documentation)!
            # Note that this shaping reward does *not* include the +20 reward for
            # completed soups (the one returned in "R").

            r_shaped = info["shaped_r_by_agent"]

            if env.agent_idx:
                r_shaped_0 = r_shaped[1]
                r_shaped_1 = r_shaped[0]
            else:
                r_shaped_0 = r_shaped[0]
                r_shaped_1 = r_shaped[1]

            combined_reward = r_shaped_0 +r_shaped_1 + R
            total_reward += r_shaped_0 +r_shaped_1 + R
            r_0 += r_shaped_0
            r_1 += r_shaped_1

            buffer.a0_state_memory[pointer] = obs0
            buffer.a1_state_memory[pointer] = obs1
            buffer.a0_action_memory[pointer] = a0
            buffer.a1_action_memory[pointer] = a1
            buffer.reward_memory[pointer] = combined_reward
            if env.agent_idx:
                buffer.a0_new_state_memory[pointer] = obs["both_agent_obs"][1]
                buffer.a1_new_state_memory[pointer] = obs["both_agent_obs"][0]
            else:
                buffer.a0_new_state_memory[pointer] = obs["both_agent_obs"][0]
                buffer.a1_new_state_memory[pointer] = obs["both_agent_obs"][1]
            buffer.terminal_memory[pointer] = terminal
            buffer.mem_counter +=1

            # Doing a mirror memory:
            pointer = buffer.mem_counter % buffer.max_mem_size

            buffer.a0_state_memory[pointer] = obs1
            buffer.a1_state_memory[pointer] = obs0
            buffer.a0_action_memory[pointer] = a1
            buffer.a1_action_memory[pointer] = a0
            buffer.reward_memory[pointer] = combined_reward
            if env.agent_idx:
                buffer.a0_new_state_memory[pointer] = obs["both_agent_obs"][0]
                buffer.a1_new_state_memory[pointer] = obs["both_agent_obs"][1]
            else:
                buffer.a0_new_state_memory[pointer] = obs["both_agent_obs"][1]
                buffer.a1_new_state_memory[pointer] = obs["both_agent_obs"][0]
            buffer.terminal_memory[pointer] = terminal
            buffer.mem_counter +=1

            #TRAIN
            if buffer.mem_counter >= batch_size:
                agent0.Q_network.optimizer.zero_grad()
                agent1.Q_network.optimizer.zero_grad()

                batch_sample = np.random.choice(min(buffer.mem_counter, buffer.max_mem_size), batch_size, replace = False)

                a0_state = T.tensor(buffer.a0_state_memory[batch_sample]).to(agent0.Q_network.device)
                a0_new_state = T.tensor(buffer.a0_new_state_memory[batch_sample]).to(agent0.Q_network.device)
                a0_action = buffer.a0_action_memory[batch_sample]
                a0_reward = T.tensor(buffer.reward_memory[batch_sample]).to(agent0.Q_network.device)
                a0_terminal = T.tensor(buffer.terminal_memory[batch_sample]).to(agent0.Q_network.device)
                a1_state = T.tensor(buffer.a1_state_memory[batch_sample]).to(agent1.Q_network.device)
                a1_new_state = T.tensor(buffer.a1_new_state_memory[batch_sample]).to(agent1.Q_network.device)
                a1_action = buffer.a1_action_memory[batch_sample]
                a1_reward = T.tensor(buffer.reward_memory[batch_sample]).to(agent1.Q_network.device)
                a1_terminal = T.tensor(buffer.terminal_memory[batch_sample]).to(agent1.Q_network.device)

                # Update Q value
                batch_index = np.arange(batch_size, dtype = np.int32)
                q_current = (agent0.Q_network.forward(a0_state)[batch_index, a0_action] +
                                agent1.Q_network.forward(a1_state)[batch_index, a1_action])

                a0_q_next = agent0.Q_target.forward(a0_new_state)
                a1_q_next = agent1.Q_target.forward(a1_new_state)
                a0_q_next[a0_terminal] = 0.0
                a1_q_next[a1_terminal] = 0.0
                a0_max_action = T.argmax(agent0.Q_network.forward(a0_new_state), dim = 1)
                a1_max_action = T.argmax(agent1.Q_network.forward(a1_new_state), dim = 1)

                # a1_max_action = T.argmax(q_eval_next, dim = 1)
                q_target = a0_reward + (agent0.gamma * a0_q_next.gather(1, a0_max_action.unsqueeze(1)).squeeze(1)+
                                        agent1.gamma * a1_q_next.gather(1, a1_max_action.unsqueeze(1)).squeeze(1))


                # LOSS FUNCTION
                # loss = F.smooth_l1_loss(q_current, q_target)
                loss = agent0.Q_network.loss(q_target,q_current).to(agent0.Q_network.device)
                loss.backward()

                agent0.Q_network.optimizer.step()
                agent1.Q_network.optimizer.step()

                #Decay epsilon
                if agent0.epsilon > agent0.eps_min:
                    agent0.epsilon = agent0.epsilon - agent0.eps_decay
                else:
                    agent0.eps_min
                if agent1.epsilon > agent1.eps_min:
                    agent1.epsilon = agent1.epsilon - agent1.eps_decay
                else:
                    agent1.eps_min

            # Accumulate the number of soups made
            num_soups_made += int(R / 20) # Each served soup generates 20 reward
            agent0.soft_update_target_network()
            agent1.soft_update_target_network()
        # upd_target_counter += 1
        # if (upd_target_counter) == 3:
        #     agent0.update_target_network()
        #     agent1.update_target_network()
        #     upd_target_counter = 0


        soup_final.append(num_soups_made)
        soup_avg = np.mean(soup_final[-100:])
        dish_pickup.append(info['episode']['ep_game_stats']['dish_pickup'])
        potting_onion.append(info['episode']['ep_game_stats']['potting_onion'])
        soup_SMA100.append(soup_avg)

        # Display status
        print("Ep {0}".format(e + 1), end=" ")
        print("shaped reward agent 0: {0}:".format(r_0), end=" ")
        print("shaped reward agent 1: {0}".format(r_1), end=" ")
        print("total_reward: ", total_reward)
        print("no of soups made: {0}".format(num_soups_made))
        print("avg soup: {0}".format(soup_avg))
        print("eps0: ", agent0.epsilon)
        print("eps1: ", agent1.epsilon)



    # The info flag returned by the environemnt contains special status info
    # specifically when terminal == True.  This information may be useful in
    # developing, debugging, and analyzing your results.  It may also be a good
    # way for you to find a metric that you can use in evaluating collaboration
    # between your agents.
    print("\nExample end-of-episode info dump:\n", info)
# Out:
# Streaming output truncated to the last 5000 lines.
# eps0:  1.0
# eps1:  1.0
# Ep 2 shaped reward agent 0: 0: shaped reward agent 1: 0 total_reward:  0
# no of soups made: 0
# avg soup: 0.0
# eps0:  0.9971100000000132
# eps1:  0.9971100000000132
# Ep 3 shaped reward agent 0: 0: shaped reward agent 1: 0 total_reward:  0
# no of soups made: 0
# avg soup: 0.0
# eps0:  0.9931100000000314
# eps1:  0.9931100000000314
# Ep 4 shaped reward agent 0: 0: shaped reward agent 1: 1 total_reward:  1
# no of soups made: 0
# avg soup: 0.0
# eps0:  0.9891100000000496
# eps1:  0.9891100000000496
# Ep 5 shaped reward agent 0: 0: shaped reward agent 1: 0 total_reward:  0
# no of soups made: 0
# avg soup: 0.0
# eps0:  0.9851100000000678
# eps1:  0.9851100000000678
# Ep 6 shaped reward agent 0: 1: shaped reward agent 1: 0 total_reward:  1
# no of soups made: 0
# avg soup: 0.0
# eps0:  0.981110000000086
# eps1:  0.981110000000086
# Ep 7 shaped reward agent 0: 0: shaped reward agent 1: 1 total_reward:  1
# no of soups made: 0
# avg soup: 0.0
# eps0:  0.9771100000001042
# eps1:  0.9771100000001042
# Ep 8 shaped reward agent 0: 0: shaped reward agent 1: 0 total_reward:  0
# no of soups made: 0
# avg soup: 0.0
# eps0:  0.9731100000001224
# eps1:  0.9731100000001224
# Ep 9 shaped reward agent 0: 6: shaped reward agent 1: 4 total_reward:  10
# no of soups made: 0
# avg soup: 0.0
# eps0:  0.9691100000001406
# eps1:  0.9691100000001406
# Ep 10 shaped reward agent 0: 1: shaped reward agent 1: 0 total_reward:  1
# no of soups made: 0
# avg soup: 0.0
# eps0:  0.9651100000001588
# eps1:  0.9651100000001588
# Ep 11 shaped reward agent 0: 7: shaped reward agent 1: 0 total_reward:  7
# no of soups made: 0
# avg soup: 0.0
# eps0:  0.961110000000177
# eps1:  0.961110000000177
# Ep 12 shaped reward agent 0: 4: shaped reward agent 1: 0 total_reward:  4
# no of soups made: 0
# avg soup: 0.0
# eps0:  0.9571100000001952
# eps1:  0.9571100000001952
# Ep 13 shaped reward agent 0: 0: shaped reward agent 1: 4 total_reward:  4
# no of soups made: 0
# avg soup: 0.0
# eps0:  0.9531100000002134
# eps1:  0.9531100000002134
# Ep 14 shaped reward agent 0: 1: shaped reward agent 1: 0 total_reward:  1
# no of soups made: 0
# avg soup: 0.0
# eps0:  0.9491100000002316
# eps1:  0.9491100000002316
# Ep 15 shaped reward agent 0: 0: shaped reward agent 1: 2 total_reward:  2
# no of soups made: 0
# avg soup: 0.0
# eps0:  0.9451100000002498
# eps1:  0.9451100000002498
# Ep 16 shaped reward agent 0: 1: shaped reward agent 1: 14 total_reward:  15
# no of soups made: 0
# avg soup: 0.0
# eps0:  0.941110000000268
# eps1:  0.941110000000268
# Ep 17 shaped reward agent 0: 0: shaped reward agent 1: 2 total_reward:  2
# no of soups made: 0
# avg soup: 0.0
# eps0:  0.9371100000002862
# eps1:  0.9371100000002862
# Ep 18 shaped reward agent 0: 0: shaped reward agent 1: 1 total_reward:  1
# no of soups made: 0
# avg soup: 0.0
# eps0:  0.9331100000003044
# eps1:  0.9331100000003044
# Ep 19 shaped reward agent 0: 2: shaped reward agent 1: 0 total_reward:  2
# no of soups made: 0
# avg soup: 0.0
# eps0:  0.9291100000003226
# eps1:  0.9291100000003226
# Ep 20 shaped reward agent 0: 0: shaped reward agent 1: 6 total_reward:  6
# no of soups made: 0
# avg soup: 0.0
# eps0:  0.9251100000003408
# eps1:  0.9251100000003408
# Ep 21 shaped reward agent 0: 4: shaped reward agent 1: 1 total_reward:  5
# no of soups made: 0
# avg soup: 0.0
# eps0:  0.921110000000359
# eps1:  0.921110000000359
# Ep 22 shaped reward agent 0: 0: shaped reward agent 1: 10 total_reward:  10
# no of soups made: 0
# avg soup: 0.0
# eps0:  0.9171100000003772
# eps1:  0.9171100000003772
# Ep 23 shaped reward agent 0: 9: shaped reward agent 1: 0 total_reward:  9
# no of soups made: 0
# avg soup: 0.0
# eps0:  0.9131100000003954
# eps1:  0.9131100000003954
# Ep 24 shaped reward agent 0: 10: shaped reward agent 1: 3 total_reward:  13
# no of soups made: 0
# avg soup: 0.0
# eps0:  0.9091100000004136
# eps1:  0.9091100000004136
# Ep 25 shaped reward agent 0: 12: shaped reward agent 1: 0 total_reward:  12
# no of soups made: 0
# avg soup: 0.0
# eps0:  0.9051100000004318
# eps1:  0.9051100000004318
# Ep 26 shaped reward agent 0: 13: shaped reward agent 1: 3 total_reward:  16
# no of soups made: 0
# avg soup: 0.0
# eps0:  0.90111000000045
# eps1:  0.90111000000045
# Ep 27 shaped reward agent 0: 8: shaped reward agent 1: 3 total_reward:  11
# no of soups made: 0
# avg soup: 0.0
# eps0:  0.8971100000004683
# eps1:  0.8971100000004683
# Ep 28 shaped reward agent 0: 5: shaped reward agent 1: 8 total_reward:  13
# no of soups made: 0
# avg soup: 0.0
# eps0:  0.8931100000004865
# eps1:  0.8931100000004865
# Ep 29 shaped reward agent 0: 0: shaped reward agent 1: 15 total_reward:  15
# no of soups made: 0
# avg soup: 0.0
# eps0:  0.8891100000005047
# eps1:  0.8891100000005047
# Ep 30 shaped reward agent 0: 5: shaped reward agent 1: 2 total_reward:  7
# no of soups made: 0
# avg soup: 0.0
# eps0:  0.8851100000005229
# eps1:  0.8851100000005229
# Ep 31 shaped reward agent 0: 9: shaped reward agent 1: 8 total_reward:  17
# no of soups made: 0
# avg soup: 0.0
# eps0:  0.8811100000005411
# eps1:  0.8811100000005411
# Ep 32 shaped reward agent 0: 4: shaped reward agent 1: 11 total_reward:  15
# no of soups made: 0
# avg soup: 0.0
# eps0:  0.8771100000005593
# eps1:  0.8771100000005593
# Ep 33 shaped reward agent 0: 11: shaped reward agent 1: 1 total_reward:  12
# no of soups made: 0
# avg soup: 0.0
# eps0:  0.8731100000005775
# eps1:  0.8731100000005775
# Ep 34 shaped reward agent 0: 16: shaped reward agent 1: 5 total_reward:  21
# no of soups made: 0
# avg soup: 0.0
# eps0:  0.8691100000005957
# eps1:  0.8691100000005957
# Ep 35 shaped reward agent 0: 2: shaped reward agent 1: 9 total_reward:  11
# no of soups made: 0
# avg soup: 0.0
# eps0:  0.8651100000006139
# eps1:  0.8651100000006139
# Ep 36 shaped reward agent 0: 10: shaped reward agent 1: 5 total_reward:  15
# no of soups made: 0
# avg soup: 0.0
# eps0:  0.8611100000006321
# eps1:  0.8611100000006321
# Ep 37 shaped reward agent 0: 9: shaped reward agent 1: 13 total_reward:  22
# no of soups made: 0
# avg soup: 0.0
# eps0:  0.8571100000006503
# eps1:  0.8571100000006503
# Ep 38 shaped reward agent 0: 7: shaped reward agent 1: 5 total_reward:  12
# no of soups made: 0
# avg soup: 0.0
# eps0:  0.8531100000006685
# eps1:  0.8531100000006685
# Ep 39 shaped reward agent 0: 18: shaped reward agent 1: 10 total_reward:  28
# no of soups made: 0
# avg soup: 0.0
# eps0:  0.8491100000006867
# eps1:  0.8491100000006867
# Ep 40 shaped reward agent 0: 1: shaped reward agent 1: 10 total_reward:  11
# no of soups made: 0
# avg soup: 0.0
# eps0:  0.8451100000007049
# eps1:  0.8451100000007049
# Ep 41 shaped reward agent 0: 10: shaped reward agent 1: 12 total_reward:  22
# no of soups made: 0
# avg soup: 0.0
# eps0:  0.8411100000007231
# eps1:  0.8411100000007231
# Ep 42 shaped reward agent 0: 9: shaped reward agent 1: 3 total_reward:  12
# no of soups made: 0
# avg soup: 0.0
# eps0:  0.8371100000007413
# eps1:  0.8371100000007413
# Ep 43 shaped reward agent 0: 3: shaped reward agent 1: 5 total_reward:  8
# no of soups made: 0
# avg soup: 0.0
# eps0:  0.8331100000007595
# eps1:  0.8331100000007595
# Ep 44 shaped reward agent 0: 12: shaped reward agent 1: 1 total_reward:  13
# no of soups made: 0
# avg soup: 0.0
# eps0:  0.8291100000007777
# eps1:  0.8291100000007777
# Ep 45 shaped reward agent 0: 5: shaped reward agent 1: 8 total_reward:  13
# no of soups made: 0
# avg soup: 0.0
# eps0:  0.8251100000007959
# eps1:  0.8251100000007959
# Ep 46 shaped reward agent 0: 15: shaped reward agent 1: 14 total_reward:  29
# no of soups made: 0
# avg soup: 0.0
# eps0:  0.8211100000008141
# eps1:  0.8211100000008141
# Ep 47 shaped reward agent 0: 10: shaped reward agent 1: 10 total_reward:  20
# no of soups made: 0
# avg soup: 0.0
# eps0:  0.8171100000008323
# eps1:  0.8171100000008323
# Ep 48 shaped reward agent 0: 9: shaped reward agent 1: 7 total_reward:  16
# no of soups made: 0
# avg soup: 0.0
# eps0:  0.8131100000008505
# eps1:  0.8131100000008505
# Ep 49 shaped reward agent 0: 3: shaped reward agent 1: 15 total_reward:  18
# no of soups made: 0
# avg soup: 0.0
# eps0:  0.8091100000008687
# eps1:  0.8091100000008687
# Ep 50 shaped reward agent 0: 5: shaped reward agent 1: 15 total_reward:  20
# no of soups made: 0
# avg soup: 0.0
# eps0:  0.805110000000887
# eps1:  0.805110000000887
# Ep 51 shaped reward agent 0: 8: shaped reward agent 1: 11 total_reward:  19
# no of soups made: 0
# avg soup: 0.0
# eps0:  0.8011100000009052
# eps1:  0.8011100000009052
# Ep 52 shaped reward agent 0: 9: shaped reward agent 1: 6 total_reward:  15
# no of soups made: 0
# avg soup: 0.0
# eps0:  0.7971100000009234
# eps1:  0.7971100000009234
# Ep 53 shaped reward agent 0: 20: shaped reward agent 1: 5 total_reward:  25
# no of soups made: 0
# avg soup: 0.0
# eps0:  0.7931100000009416
# eps1:  0.7931100000009416
# Ep 54 shaped reward agent 0: 8: shaped reward agent 1: 14 total_reward:  22
# no of soups made: 0
# avg soup: 0.0
# eps0:  0.7891100000009598
# eps1:  0.7891100000009598
# Ep 55 shaped reward agent 0: 3: shaped reward agent 1: 10 total_reward:  13
# no of soups made: 0
# avg soup: 0.0
# eps0:  0.785110000000978
# eps1:  0.785110000000978
# Ep 56 shaped reward agent 0: 17: shaped reward agent 1: 4 total_reward:  21
# no of soups made: 0
# avg soup: 0.0
# eps0:  0.7811100000009962
# eps1:  0.7811100000009962
# Ep 57 shaped reward agent 0: 7: shaped reward agent 1: 3 total_reward:  10
# no of soups made: 0
# avg soup: 0.0
# eps0:  0.7771100000010144
# eps1:  0.7771100000010144
# Ep 58 shaped reward agent 0: 4: shaped reward agent 1: 14 total_reward:  18
# no of soups made: 0
# avg soup: 0.0
# eps0:  0.7731100000010326
# eps1:  0.7731100000010326
# Ep 59 shaped reward agent 0: 5: shaped reward agent 1: 22 total_reward:  27
# no of soups made: 0
# avg soup: 0.0
# eps0:  0.7691100000010508
# eps1:  0.7691100000010508
# Ep 60 shaped reward agent 0: 18: shaped reward agent 1: 5 total_reward:  23
# no of soups made: 0
# avg soup: 0.0
# eps0:  0.765110000001069
# eps1:  0.765110000001069
# Ep 61 shaped reward agent 0: 11: shaped reward agent 1: 9 total_reward:  20
# no of soups made: 0
# avg soup: 0.0
# eps0:  0.7611100000010872
# eps1:  0.7611100000010872
# Ep 62 shaped reward agent 0: 14: shaped reward agent 1: 11 total_reward:  25
# no of soups made: 0
# avg soup: 0.0
# eps0:  0.7571100000011054
# eps1:  0.7571100000011054
# Ep 63 shaped reward agent 0: 12: shaped reward agent 1: 17 total_reward:  29
# no of soups made: 0
# avg soup: 0.0
# eps0:  0.7531100000011236
# eps1:  0.7531100000011236
# Ep 64 shaped reward agent 0: 14: shaped reward agent 1: 17 total_reward:  31
# no of soups made: 0
# avg soup: 0.0
# eps0:  0.7491100000011418
# eps1:  0.7491100000011418
# Ep 65 shaped reward agent 0: 18: shaped reward agent 1: 13 total_reward:  31
# no of soups made: 0
# avg soup: 0.0
# eps0:  0.74511000000116
# eps1:  0.74511000000116
# Ep 66 shaped reward agent 0: 8: shaped reward agent 1: 14 total_reward:  22
# no of soups made: 0
# avg soup: 0.0
# eps0:  0.7411100000011782
# eps1:  0.7411100000011782
# Ep 67 shaped reward agent 0: 13: shaped reward agent 1: 14 total_reward:  27
# no of soups made: 0
# avg soup: 0.0
# eps0:  0.7371100000011964
# eps1:  0.7371100000011964
# Ep 68 shaped reward agent 0: 19: shaped reward agent 1: 14 total_reward:  33
# no of soups made: 0
# avg soup: 0.0
# eps0:  0.7331100000012146
# eps1:  0.7331100000012146
# Ep 69 shaped reward agent 0: 16: shaped reward agent 1: 22 total_reward:  38
# no of soups made: 0
# avg soup: 0.0
# eps0:  0.7291100000012328
# eps1:  0.7291100000012328
# Ep 70 shaped reward agent 0: 23: shaped reward agent 1: 9 total_reward:  32
# no of soups made: 0
# avg soup: 0.0
# eps0:  0.725110000001251
# eps1:  0.725110000001251
# Ep 71 shaped reward agent 0: 13: shaped reward agent 1: 38 total_reward:  51
# no of soups made: 0
# avg soup: 0.0
# eps0:  0.7211100000012692
# eps1:  0.7211100000012692
# Ep 72 shaped reward agent 0: 23: shaped reward agent 1: 15 total_reward:  38
# no of soups made: 0
# avg soup: 0.0
# eps0:  0.7171100000012874
# eps1:  0.7171100000012874
# Ep 73 shaped reward agent 0: 25: shaped reward agent 1: 5 total_reward:  30
# no of soups made: 0
# avg soup: 0.0
# eps0:  0.7131100000013056
# eps1:  0.7131100000013056
# Ep 74 shaped reward agent 0: 31: shaped reward agent 1: 5 total_reward:  36
# no of soups made: 0
# avg soup: 0.0
# eps0:  0.7091100000013238
# eps1:  0.7091100000013238
# Ep 75 shaped reward agent 0: 16: shaped reward agent 1: 9 total_reward:  25
# no of soups made: 0
# avg soup: 0.0
# eps0:  0.705110000001342
# eps1:  0.705110000001342
# Ep 76 shaped reward agent 0: 26: shaped reward agent 1: 14 total_reward:  40
# no of soups made: 0
# avg soup: 0.0
# eps0:  0.7011100000013603
# eps1:  0.7011100000013603
# Ep 77 shaped reward agent 0: 13: shaped reward agent 1: 18 total_reward:  31
# no of soups made: 0
# avg soup: 0.0
# eps0:  0.6971100000013785
# eps1:  0.6971100000013785
# Ep 78 shaped reward agent 0: 24: shaped reward agent 1: 10 total_reward:  34
# no of soups made: 0
# avg soup: 0.0
# eps0:  0.6931100000013967
# eps1:  0.6931100000013967
# Ep 79 shaped reward agent 0: 36: shaped reward agent 1: 15 total_reward:  51
# no of soups made: 0
# avg soup: 0.0
# eps0:  0.6891100000014149
# eps1:  0.6891100000014149
# Ep 80 shaped reward agent 0: 16: shaped reward agent 1: 6 total_reward:  22
# no of soups made: 0
# avg soup: 0.0
# eps0:  0.6851100000014331
# eps1:  0.6851100000014331
# Ep 81 shaped reward agent 0: 36: shaped reward agent 1: 8 total_reward:  64
# no of soups made: 1
# avg soup: 0.012345679012345678
# eps0:  0.6811100000014513
# eps1:  0.6811100000014513
# Ep 82 shaped reward agent 0: 21: shaped reward agent 1: 10 total_reward:  51
# no of soups made: 1
# avg soup: 0.024390243902439025
# eps0:  0.6771100000014695
# eps1:  0.6771100000014695
# Ep 83 shaped reward agent 0: 12: shaped reward agent 1: 16 total_reward:  48
# no of soups made: 1
# avg soup: 0.03614457831325301
# eps0:  0.6731100000014877
# eps1:  0.6731100000014877
# Ep 84 shaped reward agent 0: 26: shaped reward agent 1: 21 total_reward:  47
# no of soups made: 0
# avg soup: 0.03571428571428571
# eps0:  0.6691100000015059
# eps1:  0.6691100000015059
# Ep 85 shaped reward agent 0: 30: shaped reward agent 1: 6 total_reward:  36
# no of soups made: 0
# avg soup: 0.03529411764705882
# eps0:  0.6651100000015241
# eps1:  0.6651100000015241
# Ep 86 shaped reward agent 0: 34: shaped reward agent 1: 19 total_reward:  53
# no of soups made: 0
# avg soup: 0.03488372093023256
# eps0:  0.6611100000015423
# eps1:  0.6611100000015423
# Ep 87 shaped reward agent 0: 11: shaped reward agent 1: 3 total_reward:  34
# no of soups made: 1
# avg soup: 0.04597701149425287
# eps0:  0.6571100000015605
# eps1:  0.6571100000015605
# Ep 88 shaped reward agent 0: 15: shaped reward agent 1: 20 total_reward:  35
# no of soups made: 0
# avg soup: 0.045454545454545456
# eps0:  0.6531100000015787
# eps1:  0.6531100000015787
# Ep 89 shaped reward agent 0: 14: shaped reward agent 1: 22 total_reward:  36
# no of soups made: 0
# avg soup: 0.0449438202247191
# eps0:  0.6491100000015969
# eps1:  0.6491100000015969
# Ep 90 shaped reward agent 0: 9: shaped reward agent 1: 35 total_reward:  44
# no of soups made: 0
# avg soup: 0.044444444444444446
# eps0:  0.6451100000016151
# eps1:  0.6451100000016151
# Ep 91 shaped reward agent 0: 3: shaped reward agent 1: 17 total_reward:  20
# no of soups made: 0
# avg soup: 0.04395604395604396
# eps0:  0.6411100000016333
# eps1:  0.6411100000016333
# Ep 92 shaped reward agent 0: 21: shaped reward agent 1: 31 total_reward:  52
# no of soups made: 0
# avg soup: 0.043478260869565216
# eps0:  0.6371100000016515
# eps1:  0.6371100000016515
# Ep 93 shaped reward agent 0: 23: shaped reward agent 1: 17 total_reward:  40
# no of soups made: 0
# avg soup: 0.043010752688172046
# eps0:  0.6331100000016697
# eps1:  0.6331100000016697
# Ep 94 shaped reward agent 0: 20: shaped reward agent 1: 35 total_reward:  55
# no of soups made: 0
# avg soup: 0.0425531914893617
# eps0:  0.6291100000016879
# eps1:  0.6291100000016879
# Ep 95 shaped reward agent 0: 29: shaped reward agent 1: 20 total_reward:  49
# no of soups made: 0
# avg soup: 0.042105263157894736
# eps0:  0.6251100000017061
# eps1:  0.6251100000017061
# Ep 96 shaped reward agent 0: 26: shaped reward agent 1: 43 total_reward:  69
# no of soups made: 0
# avg soup: 0.041666666666666664
# eps0:  0.6211100000017243
# eps1:  0.6211100000017243
# Ep 97 shaped reward agent 0: 46: shaped reward agent 1: 23 total_reward:  69
# no of soups made: 0
# avg soup: 0.041237113402061855
# eps0:  0.6171100000017425
# eps1:  0.6171100000017425
# Ep 98 shaped reward agent 0: 37: shaped reward agent 1: 29 total_reward:  66
# no of soups made: 0
# avg soup: 0.04081632653061224
# eps0:  0.6131100000017607
# eps1:  0.6131100000017607
# Ep 99 shaped reward agent 0: 8: shaped reward agent 1: 17 total_reward:  25
# no of soups made: 0
# avg soup: 0.04040404040404041
# eps0:  0.609110000001779
# eps1:  0.609110000001779
# Ep 100 shaped reward agent 0: 15: shaped reward agent 1: 25 total_reward:  40
# no of soups made: 0
# avg soup: 0.04
# eps0:  0.6051100000017972
# eps1:  0.6051100000017972
# Ep 101 shaped reward agent 0: 31: shaped reward agent 1: 16 total_reward:  47
# no of soups made: 0
# avg soup: 0.04
# eps0:  0.6011100000018154
# eps1:  0.6011100000018154
# Ep 102 shaped reward agent 0: 25: shaped reward agent 1: 27 total_reward:  52
# no of soups made: 0
# avg soup: 0.04
# eps0:  0.5971100000018336
# eps1:  0.5971100000018336
# Ep 103 shaped reward agent 0: 43: shaped reward agent 1: 13 total_reward:  56
# no of soups made: 0
# avg soup: 0.04
# eps0:  0.5931100000018518
# eps1:  0.5931100000018518
# Ep 104 shaped reward agent 0: 37: shaped reward agent 1: 21 total_reward:  58
# no of soups made: 0
# avg soup: 0.04
# eps0:  0.58911000000187
# eps1:  0.58911000000187
# Ep 105 shaped reward agent 0: 23: shaped reward agent 1: 37 total_reward:  60
# no of soups made: 0
# avg soup: 0.04
# eps0:  0.5851100000018882
# eps1:  0.5851100000018882
# Ep 106 shaped reward agent 0: 51: shaped reward agent 1: 20 total_reward:  71
# no of soups made: 0
# avg soup: 0.04
# eps0:  0.5811100000019064
# eps1:  0.5811100000019064
# Ep 107 shaped reward agent 0: 30: shaped reward agent 1: 19 total_reward:  49
# no of soups made: 0
# avg soup: 0.04
# eps0:  0.5771100000019246
# eps1:  0.5771100000019246
# Ep 108 shaped reward agent 0: 20: shaped reward agent 1: 38 total_reward:  58
# no of soups made: 0
# avg soup: 0.04
# eps0:  0.5731100000019428
# eps1:  0.5731100000019428
# Ep 109 shaped reward agent 0: 31: shaped reward agent 1: 17 total_reward:  48
# no of soups made: 0
# avg soup: 0.04
# eps0:  0.569110000001961
# eps1:  0.569110000001961
# Ep 110 shaped reward agent 0: 33: shaped reward agent 1: 23 total_reward:  56
# no of soups made: 0
# avg soup: 0.04
# eps0:  0.5651100000019792
# eps1:  0.5651100000019792
# Ep 111 shaped reward agent 0: 18: shaped reward agent 1: 25 total_reward:  43
# no of soups made: 0
# avg soup: 0.04
# eps0:  0.5611100000019974
# eps1:  0.5611100000019974
# Ep 112 shaped reward agent 0: 70: shaped reward agent 1: 21 total_reward:  91
# no of soups made: 0
# avg soup: 0.04
# eps0:  0.5571100000020156
# eps1:  0.5571100000020156
# Ep 113 shaped reward agent 0: 29: shaped reward agent 1: 17 total_reward:  46
# no of soups made: 0
# avg soup: 0.04
# eps0:  0.5531100000020338
# eps1:  0.5531100000020338
# Ep 114 shaped reward agent 0: 12: shaped reward agent 1: 59 total_reward:  71
# no of soups made: 0
# avg soup: 0.04
# eps0:  0.549110000002052
# eps1:  0.549110000002052
# Ep 115 shaped reward agent 0: 29: shaped reward agent 1: 22 total_reward:  51
# no of soups made: 0
# avg soup: 0.04
# eps0:  0.5451100000020702
# eps1:  0.5451100000020702
# Ep 116 shaped reward agent 0: 26: shaped reward agent 1: 22 total_reward:  68
# no of soups made: 1
# avg soup: 0.05
# eps0:  0.5411100000020884
# eps1:  0.5411100000020884
# Ep 117 shaped reward agent 0: 22: shaped reward agent 1: 17 total_reward:  39
# no of soups made: 0
# avg soup: 0.05
# eps0:  0.5371100000021066
# eps1:  0.5371100000021066
# Ep 118 shaped reward agent 0: 37: shaped reward agent 1: 17 total_reward:  54
# no of soups made: 0
# avg soup: 0.05
# eps0:  0.5331100000021248
# eps1:  0.5331100000021248
# Ep 119 shaped reward agent 0: 21: shaped reward agent 1: 40 total_reward:  61
# no of soups made: 0
# avg soup: 0.05
# eps0:  0.529110000002143
# eps1:  0.529110000002143
# Ep 120 shaped reward agent 0: 35: shaped reward agent 1: 28 total_reward:  63
# no of soups made: 0
# avg soup: 0.05
# eps0:  0.5251100000021612
# eps1:  0.5251100000021612
# Ep 121 shaped reward agent 0: 42: shaped reward agent 1: 25 total_reward:  87
# no of soups made: 1
# avg soup: 0.06
# eps0:  0.5211100000021794
# eps1:  0.5211100000021794
# Ep 122 shaped reward agent 0: 18: shaped reward agent 1: 24 total_reward:  42
# no of soups made: 0
# avg soup: 0.06
# eps0:  0.5171100000021976
# eps1:  0.5171100000021976
# Ep 123 shaped reward agent 0: 41: shaped reward agent 1: 21 total_reward:  62
# no of soups made: 0
# avg soup: 0.06
# eps0:  0.5131100000022158
# eps1:  0.5131100000022158
# Ep 124 shaped reward agent 0: 25: shaped reward agent 1: 23 total_reward:  48
# no of soups made: 0
# avg soup: 0.06
# eps0:  0.509110000002234
# eps1:  0.509110000002234
# Ep 125 shaped reward agent 0: 28: shaped reward agent 1: 34 total_reward:  62
# no of soups made: 0
# avg soup: 0.06
# eps0:  0.5051100000022523
# eps1:  0.5051100000022523
# Ep 126 shaped reward agent 0: 25: shaped reward agent 1: 46 total_reward:  71
# no of soups made: 0
# avg soup: 0.06
# eps0:  0.5011100000022705
# eps1:  0.5011100000022705
# Ep 127 shaped reward agent 0: 27: shaped reward agent 1: 34 total_reward:  61
# no of soups made: 0
# avg soup: 0.06
# eps0:  0.4971100000022726
# eps1:  0.4971100000022726
# Ep 128 shaped reward agent 0: 39: shaped reward agent 1: 37 total_reward:  76
# no of soups made: 0
# avg soup: 0.06
# eps0:  0.4931100000022686
# eps1:  0.4931100000022686
# Ep 129 shaped reward agent 0: 25: shaped reward agent 1: 22 total_reward:  47
# no of soups made: 0
# avg soup: 0.06
# eps0:  0.4891100000022646
# eps1:  0.4891100000022646
# Ep 130 shaped reward agent 0: 58: shaped reward agent 1: 21 total_reward:  79
# no of soups made: 0
# avg soup: 0.06
# eps0:  0.4851100000022606
# eps1:  0.4851100000022606
# Ep 131 shaped reward agent 0: 41: shaped reward agent 1: 33 total_reward:  74
# no of soups made: 0
# avg soup: 0.06
# eps0:  0.4811100000022566
# eps1:  0.4811100000022566
# Ep 132 shaped reward agent 0: 10: shaped reward agent 1: 10 total_reward:  20
# no of soups made: 0
# avg soup: 0.06
# eps0:  0.4771100000022526
# eps1:  0.4771100000022526
# Ep 133 shaped reward agent 0: 39: shaped reward agent 1: 21 total_reward:  60
# no of soups made: 0
# avg soup: 0.06
# eps0:  0.4731100000022486
# eps1:  0.4731100000022486
# Ep 134 shaped reward agent 0: 15: shaped reward agent 1: 23 total_reward:  38
# no of soups made: 0
# avg soup: 0.06
# eps0:  0.4691100000022446
# eps1:  0.4691100000022446
# Ep 135 shaped reward agent 0: 41: shaped reward agent 1: 26 total_reward:  107
# no of soups made: 2
# avg soup: 0.08
# eps0:  0.4651100000022406
# eps1:  0.4651100000022406
# Ep 136 shaped reward agent 0: 26: shaped reward agent 1: 43 total_reward:  69
# no of soups made: 0
# avg soup: 0.08
# eps0:  0.4611100000022366
# eps1:  0.4611100000022366
# Ep 137 shaped reward agent 0: 23: shaped reward agent 1: 35 total_reward:  78
# no of soups made: 1
# avg soup: 0.09
# eps0:  0.4571100000022326
# eps1:  0.4571100000022326
# Ep 138 shaped reward agent 0: 45: shaped reward agent 1: 27 total_reward:  72
# no of soups made: 0
# avg soup: 0.09
# eps0:  0.4531100000022286
# eps1:  0.4531100000022286
# Ep 139 shaped reward agent 0: 32: shaped reward agent 1: 29 total_reward:  61
# no of soups made: 0
# avg soup: 0.09
# eps0:  0.4491100000022246
# eps1:  0.4491100000022246
# Ep 140 shaped reward agent 0: 19: shaped reward agent 1: 7 total_reward:  26
# no of soups made: 0
# avg soup: 0.09
# eps0:  0.4451100000022206
# eps1:  0.4451100000022206
# Ep 141 shaped reward agent 0: 42: shaped reward agent 1: 22 total_reward:  104
# no of soups made: 2
# avg soup: 0.11
# eps0:  0.4411100000022166
# eps1:  0.4411100000022166
# Ep 142 shaped reward agent 0: 41: shaped reward agent 1: 32 total_reward:  73
# no of soups made: 0
# avg soup: 0.11
# eps0:  0.4371100000022126
# eps1:  0.4371100000022126
# Ep 143 shaped reward agent 0: 25: shaped reward agent 1: 28 total_reward:  93
# no of soups made: 2
# avg soup: 0.13
# eps0:  0.4331100000022086
# eps1:  0.4331100000022086
# Ep 144 shaped reward agent 0: 34: shaped reward agent 1: 33 total_reward:  67
# no of soups made: 0
# avg soup: 0.13
# eps0:  0.4291100000022046
# eps1:  0.4291100000022046
# Ep 145 shaped reward agent 0: 27: shaped reward agent 1: 27 total_reward:  74
# no of soups made: 1
# avg soup: 0.14
# eps0:  0.4251100000022006
# eps1:  0.4251100000022006
# Ep 146 shaped reward agent 0: 6: shaped reward agent 1: 9 total_reward:  15
# no of soups made: 0
# avg soup: 0.14
# eps0:  0.4211100000021966
# eps1:  0.4211100000021966
# Ep 147 shaped reward agent 0: 20: shaped reward agent 1: 32 total_reward:  52
# no of soups made: 0
# avg soup: 0.14
# eps0:  0.4171100000021926
# eps1:  0.4171100000021926
# Ep 148 shaped reward agent 0: 13: shaped reward agent 1: 21 total_reward:  34
# no of soups made: 0
# avg soup: 0.14
# eps0:  0.4131100000021886
# eps1:  0.4131100000021886
# Ep 149 shaped reward agent 0: 21: shaped reward agent 1: 5 total_reward:  46
# no of soups made: 1
# avg soup: 0.15
# eps0:  0.4091100000021846
# eps1:  0.4091100000021846
# Ep 150 shaped reward agent 0: 15: shaped reward agent 1: 9 total_reward:  24
# no of soups made: 0
# avg soup: 0.15
# eps0:  0.4051100000021806
# eps1:  0.4051100000021806
# Ep 151 shaped reward agent 0: 17: shaped reward agent 1: 19 total_reward:  36
# no of soups made: 0
# avg soup: 0.15
# eps0:  0.4011100000021766
# eps1:  0.4011100000021766
# Ep 152 shaped reward agent 0: 30: shaped reward agent 1: 18 total_reward:  48
# no of soups made: 0
# avg soup: 0.15
# eps0:  0.3971100000021726
# eps1:  0.3971100000021726
# Ep 153 shaped reward agent 0: 50: shaped reward agent 1: 21 total_reward:  111
# no of soups made: 2
# avg soup: 0.17
# eps0:  0.3931100000021686
# eps1:  0.3931100000021686
# Ep 154 shaped reward agent 0: 34: shaped reward agent 1: 18 total_reward:  52
# no of soups made: 0
# avg soup: 0.17
# eps0:  0.3891100000021646
# eps1:  0.3891100000021646
# Ep 155 shaped reward agent 0: 12: shaped reward agent 1: 33 total_reward:  45
# no of soups made: 0
# avg soup: 0.17
# eps0:  0.3851100000021606
# eps1:  0.3851100000021606
# Ep 156 shaped reward agent 0: 33: shaped reward agent 1: 29 total_reward:  62
# no of soups made: 0
# avg soup: 0.17
# eps0:  0.3811100000021566
# eps1:  0.3811100000021566
# Ep 157 shaped reward agent 0: 33: shaped reward agent 1: 21 total_reward:  74
# no of soups made: 1
# avg soup: 0.18
# eps0:  0.3771100000021526
# eps1:  0.3771100000021526
# Ep 158 shaped reward agent 0: 45: shaped reward agent 1: 25 total_reward:  70
# no of soups made: 0
# avg soup: 0.18
# eps0:  0.3731100000021486
# eps1:  0.3731100000021486
# Ep 159 shaped reward agent 0: 43: shaped reward agent 1: 29 total_reward:  72
# no of soups made: 0
# avg soup: 0.18
# eps0:  0.3691100000021446
# eps1:  0.3691100000021446
# Ep 160 shaped reward agent 0: 17: shaped reward agent 1: 40 total_reward:  77
# no of soups made: 1
# avg soup: 0.19
# eps0:  0.3651100000021406
# eps1:  0.3651100000021406
# Ep 161 shaped reward agent 0: 31: shaped reward agent 1: 30 total_reward:  61
# no of soups made: 0
# avg soup: 0.19
# eps0:  0.3611100000021366
# eps1:  0.3611100000021366
# Ep 162 shaped reward agent 0: 37: shaped reward agent 1: 12 total_reward:  69
# no of soups made: 1
# avg soup: 0.2
# eps0:  0.3571100000021326
# eps1:  0.3571100000021326
# Ep 163 shaped reward agent 0: 36: shaped reward agent 1: 29 total_reward:  85
# no of soups made: 1
# avg soup: 0.21
# eps0:  0.3531100000021286
# eps1:  0.3531100000021286
# Ep 164 shaped reward agent 0: 36: shaped reward agent 1: 21 total_reward:  77
# no of soups made: 1
# avg soup: 0.22
# eps0:  0.3491100000021246
# eps1:  0.3491100000021246
# Ep 165 shaped reward agent 0: 31: shaped reward agent 1: 41 total_reward:  92
# no of soups made: 1
# avg soup: 0.23
# eps0:  0.3451100000021206
# eps1:  0.3451100000021206
# Ep 166 shaped reward agent 0: 49: shaped reward agent 1: 31 total_reward:  120
# no of soups made: 2
# avg soup: 0.25
# eps0:  0.3411100000021166
# eps1:  0.3411100000021166
# Ep 167 shaped reward agent 0: 30: shaped reward agent 1: 40 total_reward:  90
# no of soups made: 1
# avg soup: 0.26
# eps0:  0.3371100000021126
# eps1:  0.3371100000021126
# Ep 168 shaped reward agent 0: 49: shaped reward agent 1: 54 total_reward:  103
# no of soups made: 0
# avg soup: 0.26
# eps0:  0.3331100000021086
# eps1:  0.3331100000021086
# Ep 169 shaped reward agent 0: 43: shaped reward agent 1: 36 total_reward:  119
# no of soups made: 2
# avg soup: 0.28
# eps0:  0.3291100000021046
# eps1:  0.3291100000021046
# Ep 170 shaped reward agent 0: 63: shaped reward agent 1: 32 total_reward:  195
# no of soups made: 5
# avg soup: 0.33
# eps0:  0.3251100000021006
# eps1:  0.3251100000021006
# Ep 171 shaped reward agent 0: 17: shaped reward agent 1: 44 total_reward:  61
# no of soups made: 0
# avg soup: 0.33
# eps0:  0.3211100000020966
# eps1:  0.3211100000020966
# Ep 172 shaped reward agent 0: 36: shaped reward agent 1: 49 total_reward:  85
# no of soups made: 0
# avg soup: 0.33
# eps0:  0.3171100000020926
# eps1:  0.3171100000020926
# Ep 173 shaped reward agent 0: 49: shaped reward agent 1: 44 total_reward:  113
# no of soups made: 1
# avg soup: 0.34
# eps0:  0.3131100000020886
# eps1:  0.3131100000020886
# Ep 174 shaped reward agent 0: 56: shaped reward agent 1: 38 total_reward:  94
# no of soups made: 0
# avg soup: 0.34
# eps0:  0.3091100000020846
# eps1:  0.3091100000020846
# Ep 175 shaped reward agent 0: 29: shaped reward agent 1: 25 total_reward:  54
# no of soups made: 0
# avg soup: 0.34
# eps0:  0.3051100000020806
# eps1:  0.3051100000020806
# Ep 176 shaped reward agent 0: 44: shaped reward agent 1: 10 total_reward:  54
# no of soups made: 0
# avg soup: 0.34
# eps0:  0.3011100000020766
# eps1:  0.3011100000020766
# Ep 177 shaped reward agent 0: 27: shaped reward agent 1: 27 total_reward:  74
# no of soups made: 1
# avg soup: 0.35
# eps0:  0.2971100000020726
# eps1:  0.2971100000020726
# Ep 178 shaped reward agent 0: 48: shaped reward agent 1: 29 total_reward:  97
# no of soups made: 1
# avg soup: 0.36
# eps0:  0.2931100000020686
# eps1:  0.2931100000020686
# Ep 179 shaped reward agent 0: 20: shaped reward agent 1: 13 total_reward:  33
# no of soups made: 0
# avg soup: 0.36
# eps0:  0.2891100000020646
# eps1:  0.2891100000020646
# Ep 180 shaped reward agent 0: 50: shaped reward agent 1: 24 total_reward:  114
# no of soups made: 2
# avg soup: 0.38
# eps0:  0.2851100000020606
# eps1:  0.2851100000020606
# Ep 181 shaped reward agent 0: 35: shaped reward agent 1: 50 total_reward:  105
# no of soups made: 1
# avg soup: 0.38
# eps0:  0.2811100000020566
# eps1:  0.2811100000020566
# Ep 182 shaped reward agent 0: 21: shaped reward agent 1: 17 total_reward:  58
# no of soups made: 1
# avg soup: 0.38
# eps0:  0.2771100000020526
# eps1:  0.2771100000020526
# Ep 183 shaped reward agent 0: 42: shaped reward agent 1: 32 total_reward:  74
# no of soups made: 0
# avg soup: 0.37
# eps0:  0.2731100000020486
# eps1:  0.2731100000020486
# Ep 184 shaped reward agent 0: 45: shaped reward agent 1: 42 total_reward:  87
# no of soups made: 0
# avg soup: 0.37
# eps0:  0.2691100000020446
# eps1:  0.2691100000020446
# Ep 185 shaped reward agent 0: 62: shaped reward agent 1: 39 total_reward:  101
# no of soups made: 0
# avg soup: 0.37
# eps0:  0.2651100000020406
# eps1:  0.2651100000020406
# Ep 186 shaped reward agent 0: 41: shaped reward agent 1: 33 total_reward:  74
# no of soups made: 0
# avg soup: 0.37
# eps0:  0.2611100000020366
# eps1:  0.2611100000020366
# Ep 187 shaped reward agent 0: 56: shaped reward agent 1: 32 total_reward:  88
# no of soups made: 0
# avg soup: 0.36
# eps0:  0.2571100000020326
# eps1:  0.2571100000020326
# Ep 188 shaped reward agent 0: 63: shaped reward agent 1: 33 total_reward:  116
# no of soups made: 1
# avg soup: 0.37
# eps0:  0.2531100000020286
# eps1:  0.2531100000020286
# Ep 189 shaped reward agent 0: 37: shaped reward agent 1: 29 total_reward:  86
# no of soups made: 1
# avg soup: 0.38
# eps0:  0.2491100000020246
# eps1:  0.2491100000020246
# Ep 190 shaped reward agent 0: 20: shaped reward agent 1: 54 total_reward:  114
# no of soups made: 2
# avg soup: 0.4
# eps0:  0.2451100000020206
# eps1:  0.2451100000020206
# Ep 191 shaped reward agent 0: 22: shaped reward agent 1: 45 total_reward:  87
# no of soups made: 1
# avg soup: 0.41
# eps0:  0.2411100000020166
# eps1:  0.2411100000020166
# Ep 192 shaped reward agent 0: 39: shaped reward agent 1: 50 total_reward:  109
# no of soups made: 1
# avg soup: 0.42
# eps0:  0.2371100000020126
# eps1:  0.2371100000020126
# Ep 193 shaped reward agent 0: 31: shaped reward agent 1: 49 total_reward:  120
# no of soups made: 2
# avg soup: 0.44
# eps0:  0.2331100000020086
# eps1:  0.2331100000020086
# Ep 194 shaped reward agent 0: 47: shaped reward agent 1: 41 total_reward:  108
# no of soups made: 1
# avg soup: 0.45
# eps0:  0.2291100000020046
# eps1:  0.2291100000020046
# Ep 195 shaped reward agent 0: 56: shaped reward agent 1: 23 total_reward:  79
# no of soups made: 0
# avg soup: 0.45
# eps0:  0.2251100000020006
# eps1:  0.2251100000020006
# Ep 196 shaped reward agent 0: 44: shaped reward agent 1: 56 total_reward:  100
# no of soups made: 0
# avg soup: 0.45
# eps0:  0.2211100000019966
# eps1:  0.2211100000019966
# Ep 197 shaped reward agent 0: 69: shaped reward agent 1: 30 total_reward:  139
# no of soups made: 2
# avg soup: 0.47
# eps0:  0.2171100000019926
# eps1:  0.2171100000019926
# Ep 198 shaped reward agent 0: 53: shaped reward agent 1: 34 total_reward:  147
# no of soups made: 3
# avg soup: 0.5
# eps0:  0.2131100000019886
# eps1:  0.2131100000019886
# Ep 199 shaped reward agent 0: 40: shaped reward agent 1: 51 total_reward:  111
# no of soups made: 1
# avg soup: 0.51
# eps0:  0.2091100000019846
# eps1:  0.2091100000019846
# Ep 200 shaped reward agent 0: 57: shaped reward agent 1: 41 total_reward:  98
# no of soups made: 0
# avg soup: 0.51
# eps0:  0.2051100000019806
# eps1:  0.2051100000019806
# Ep 201 shaped reward agent 0: 61: shaped reward agent 1: 33 total_reward:  94
# no of soups made: 0
# avg soup: 0.51
# eps0:  0.2011100000019766
# eps1:  0.2011100000019766
# Ep 202 shaped reward agent 0: 34: shaped reward agent 1: 50 total_reward:  104
# no of soups made: 1
# avg soup: 0.52
# eps0:  0.1971100000019726
# eps1:  0.1971100000019726
# Ep 203 shaped reward agent 0: 27: shaped reward agent 1: 29 total_reward:  76
# no of soups made: 1
# avg soup: 0.53
# eps0:  0.1931100000019686
# eps1:  0.1931100000019686
# Ep 204 shaped reward agent 0: 36: shaped reward agent 1: 41 total_reward:  97
# no of soups made: 1
# avg soup: 0.54
# eps0:  0.1891100000019646
# eps1:  0.1891100000019646
# Ep 205 shaped reward agent 0: 48: shaped reward agent 1: 34 total_reward:  142
# no of soups made: 3
# avg soup: 0.57
# eps0:  0.1851100000019606
# eps1:  0.1851100000019606
# Ep 206 shaped reward agent 0: 33: shaped reward agent 1: 51 total_reward:  84
# no of soups made: 0
# avg soup: 0.57
# eps0:  0.1811100000019566
# eps1:  0.1811100000019566
# Ep 207 shaped reward agent 0: 58: shaped reward agent 1: 33 total_reward:  131
# no of soups made: 2
# avg soup: 0.59
# eps0:  0.1771100000019526
# eps1:  0.1771100000019526
# Ep 208 shaped reward agent 0: 40: shaped reward agent 1: 65 total_reward:  105
# no of soups made: 0
# avg soup: 0.59
# eps0:  0.1731100000019486
# eps1:  0.1731100000019486
# Ep 209 shaped reward agent 0: 23: shaped reward agent 1: 70 total_reward:  173
# no of soups made: 4
# avg soup: 0.63
# eps0:  0.1691100000019446
# eps1:  0.1691100000019446
# Ep 210 shaped reward agent 0: 17: shaped reward agent 1: 49 total_reward:  86
# no of soups made: 1
# avg soup: 0.64
# eps0:  0.1651100000019406
# eps1:  0.1651100000019406
# Ep 211 shaped reward agent 0: 23: shaped reward agent 1: 41 total_reward:  104
# no of soups made: 2
# avg soup: 0.66
# eps0:  0.1611100000019366
# eps1:  0.1611100000019366
# Ep 212 shaped reward agent 0: 75: shaped reward agent 1: 30 total_reward:  165
# no of soups made: 3
# avg soup: 0.69
# eps0:  0.1571100000019326
# eps1:  0.1571100000019326
# Ep 213 shaped reward agent 0: 50: shaped reward agent 1: 32 total_reward:  102
# no of soups made: 1
# avg soup: 0.7
# eps0:  0.1531100000019286
# eps1:  0.1531100000019286
# Ep 214 shaped reward agent 0: 47: shaped reward agent 1: 31 total_reward:  98
# no of soups made: 1
# avg soup: 0.71
# eps0:  0.1491100000019246
# eps1:  0.1491100000019246
# Ep 215 shaped reward agent 0: 37: shaped reward agent 1: 53 total_reward:  150
# no of soups made: 3
# avg soup: 0.74
# eps0:  0.1451100000019206
# eps1:  0.1451100000019206
# Ep 216 shaped reward agent 0: 27: shaped reward agent 1: 58 total_reward:  105
# no of soups made: 1
# avg soup: 0.74
# eps0:  0.1411100000019166
# eps1:  0.1411100000019166
# Ep 217 shaped reward agent 0: 47: shaped reward agent 1: 80 total_reward:  127
# no of soups made: 0
# avg soup: 0.74
# eps0:  0.1371100000019126
# eps1:  0.1371100000019126
# Ep 218 shaped reward agent 0: 59: shaped reward agent 1: 28 total_reward:  127
# no of soups made: 2
# avg soup: 0.76
# eps0:  0.1331100000019086
# eps1:  0.1331100000019086
# Ep 219 shaped reward agent 0: 29: shaped reward agent 1: 19 total_reward:  68
# no of soups made: 1
# avg soup: 0.77
# eps0:  0.1291100000019046
# eps1:  0.1291100000019046
# Ep 220 shaped reward agent 0: 63: shaped reward agent 1: 46 total_reward:  129
# no of soups made: 1
# avg soup: 0.78
# eps0:  0.1251100000019006
# eps1:  0.1251100000019006
# Ep 221 shaped reward agent 0: 48: shaped reward agent 1: 85 total_reward:  153
# no of soups made: 1
# avg soup: 0.78
# eps0:  0.12111000000190199
# eps1:  0.12111000000190199
# Ep 222 shaped reward agent 0: 41: shaped reward agent 1: 35 total_reward:  96
# no of soups made: 1
# avg soup: 0.79
# eps0:  0.11711000000190354
# eps1:  0.11711000000190354
# Ep 223 shaped reward agent 0: 53: shaped reward agent 1: 39 total_reward:  132
# no of soups made: 2
# avg soup: 0.81
# eps0:  0.11311000000190509
# eps1:  0.11311000000190509
# Ep 224 shaped reward agent 0: 59: shaped reward agent 1: 32 total_reward:  131
# no of soups made: 2
# avg soup: 0.83
# eps0:  0.10911000000190664
# eps1:  0.10911000000190664
# Ep 225 shaped reward agent 0: 48: shaped reward agent 1: 32 total_reward:  80
# no of soups made: 0
# avg soup: 0.83
# eps0:  0.10511000000190819
# eps1:  0.10511000000190819
# Ep 226 shaped reward agent 0: 58: shaped reward agent 1: 27 total_reward:  145
# no of soups made: 3
# avg soup: 0.86
# eps0:  0.10111000000190974
# eps1:  0.10111000000190974
# Ep 227 shaped reward agent 0: 32: shaped reward agent 1: 60 total_reward:  112
# no of soups made: 1
# avg soup: 0.87
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 228 shaped reward agent 0: 46: shaped reward agent 1: 107 total_reward:  193
# no of soups made: 2
# avg soup: 0.89
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 229 shaped reward agent 0: 64: shaped reward agent 1: 34 total_reward:  98
# no of soups made: 0
# avg soup: 0.89
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 230 shaped reward agent 0: 51: shaped reward agent 1: 32 total_reward:  103
# no of soups made: 1
# avg soup: 0.9
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 231 shaped reward agent 0: 42: shaped reward agent 1: 31 total_reward:  73
# no of soups made: 0
# avg soup: 0.9
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 232 shaped reward agent 0: 66: shaped reward agent 1: 106 total_reward:  212
# no of soups made: 2
# avg soup: 0.92
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 233 shaped reward agent 0: 39: shaped reward agent 1: 27 total_reward:  106
# no of soups made: 2
# avg soup: 0.94
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 234 shaped reward agent 0: 28: shaped reward agent 1: 35 total_reward:  63
# no of soups made: 0
# avg soup: 0.94
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 235 shaped reward agent 0: 44: shaped reward agent 1: 31 total_reward:  95
# no of soups made: 1
# avg soup: 0.93
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 236 shaped reward agent 0: 38: shaped reward agent 1: 69 total_reward:  127
# no of soups made: 1
# avg soup: 0.94
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 237 shaped reward agent 0: 54: shaped reward agent 1: 39 total_reward:  133
# no of soups made: 2
# avg soup: 0.95
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 238 shaped reward agent 0: 44: shaped reward agent 1: 61 total_reward:  145
# no of soups made: 2
# avg soup: 0.97
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 239 shaped reward agent 0: 57: shaped reward agent 1: 48 total_reward:  105
# no of soups made: 0
# avg soup: 0.97
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 240 shaped reward agent 0: 40: shaped reward agent 1: 40 total_reward:  80
# no of soups made: 0
# avg soup: 0.97
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 241 shaped reward agent 0: 84: shaped reward agent 1: 41 total_reward:  125
# no of soups made: 0
# avg soup: 0.95
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 242 shaped reward agent 0: 37: shaped reward agent 1: 55 total_reward:  92
# no of soups made: 0
# avg soup: 0.95
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 243 shaped reward agent 0: 62: shaped reward agent 1: 46 total_reward:  108
# no of soups made: 0
# avg soup: 0.93
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 244 shaped reward agent 0: 38: shaped reward agent 1: 54 total_reward:  132
# no of soups made: 2
# avg soup: 0.95
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 245 shaped reward agent 0: 52: shaped reward agent 1: 51 total_reward:  123
# no of soups made: 1
# avg soup: 0.95
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 246 shaped reward agent 0: 53: shaped reward agent 1: 49 total_reward:  162
# no of soups made: 3
# avg soup: 0.98
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 247 shaped reward agent 0: 52: shaped reward agent 1: 51 total_reward:  103
# no of soups made: 0
# avg soup: 0.98
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 248 shaped reward agent 0: 74: shaped reward agent 1: 42 total_reward:  156
# no of soups made: 2
# avg soup: 1.0
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 249 shaped reward agent 0: 41: shaped reward agent 1: 63 total_reward:  124
# no of soups made: 1
# avg soup: 1.0
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 250 shaped reward agent 0: 59: shaped reward agent 1: 49 total_reward:  128
# no of soups made: 1
# avg soup: 1.01
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 251 shaped reward agent 0: 66: shaped reward agent 1: 35 total_reward:  101
# no of soups made: 0
# avg soup: 1.01
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 252 shaped reward agent 0: 36: shaped reward agent 1: 45 total_reward:  121
# no of soups made: 2
# avg soup: 1.03
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 253 shaped reward agent 0: 38: shaped reward agent 1: 67 total_reward:  165
# no of soups made: 3
# avg soup: 1.04
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 254 shaped reward agent 0: 36: shaped reward agent 1: 56 total_reward:  132
# no of soups made: 2
# avg soup: 1.06
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 255 shaped reward agent 0: 53: shaped reward agent 1: 37 total_reward:  110
# no of soups made: 1
# avg soup: 1.07
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 256 shaped reward agent 0: 59: shaped reward agent 1: 32 total_reward:  171
# no of soups made: 4
# avg soup: 1.11
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 257 shaped reward agent 0: 40: shaped reward agent 1: 70 total_reward:  130
# no of soups made: 1
# avg soup: 1.11
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 258 shaped reward agent 0: 66: shaped reward agent 1: 45 total_reward:  171
# no of soups made: 3
# avg soup: 1.14
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 259 shaped reward agent 0: 59: shaped reward agent 1: 46 total_reward:  125
# no of soups made: 1
# avg soup: 1.15
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 260 shaped reward agent 0: 25: shaped reward agent 1: 45 total_reward:  110
# no of soups made: 2
# avg soup: 1.16
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 261 shaped reward agent 0: 69: shaped reward agent 1: 37 total_reward:  186
# no of soups made: 4
# avg soup: 1.2
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 262 shaped reward agent 0: 51: shaped reward agent 1: 32 total_reward:  123
# no of soups made: 2
# avg soup: 1.21
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 263 shaped reward agent 0: 41: shaped reward agent 1: 65 total_reward:  146
# no of soups made: 2
# avg soup: 1.22
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 264 shaped reward agent 0: 40: shaped reward agent 1: 33 total_reward:  113
# no of soups made: 2
# avg soup: 1.23
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 265 shaped reward agent 0: 42: shaped reward agent 1: 31 total_reward:  93
# no of soups made: 1
# avg soup: 1.23
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 266 shaped reward agent 0: 55: shaped reward agent 1: 36 total_reward:  131
# no of soups made: 2
# avg soup: 1.23
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 267 shaped reward agent 0: 65: shaped reward agent 1: 31 total_reward:  96
# no of soups made: 0
# avg soup: 1.22
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 268 shaped reward agent 0: 74: shaped reward agent 1: 41 total_reward:  195
# no of soups made: 4
# avg soup: 1.26
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 269 shaped reward agent 0: 54: shaped reward agent 1: 37 total_reward:  111
# no of soups made: 1
# avg soup: 1.25
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 270 shaped reward agent 0: 42: shaped reward agent 1: 59 total_reward:  101
# no of soups made: 0
# avg soup: 1.2
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 271 shaped reward agent 0: 66: shaped reward agent 1: 28 total_reward:  154
# no of soups made: 3
# avg soup: 1.23
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 272 shaped reward agent 0: 44: shaped reward agent 1: 74 total_reward:  138
# no of soups made: 1
# avg soup: 1.24
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 273 shaped reward agent 0: 32: shaped reward agent 1: 51 total_reward:  103
# no of soups made: 1
# avg soup: 1.24
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 274 shaped reward agent 0: 71: shaped reward agent 1: 32 total_reward:  203
# no of soups made: 5
# avg soup: 1.29
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 275 shaped reward agent 0: 47: shaped reward agent 1: 69 total_reward:  176
# no of soups made: 3
# avg soup: 1.32
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 276 shaped reward agent 0: 44: shaped reward agent 1: 43 total_reward:  107
# no of soups made: 1
# avg soup: 1.33
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 277 shaped reward agent 0: 58: shaped reward agent 1: 45 total_reward:  163
# no of soups made: 3
# avg soup: 1.35
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 278 shaped reward agent 0: 46: shaped reward agent 1: 58 total_reward:  164
# no of soups made: 3
# avg soup: 1.37
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 279 shaped reward agent 0: 91: shaped reward agent 1: 42 total_reward:  233
# no of soups made: 5
# avg soup: 1.42
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 280 shaped reward agent 0: 54: shaped reward agent 1: 83 total_reward:  197
# no of soups made: 3
# avg soup: 1.43
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 281 shaped reward agent 0: 42: shaped reward agent 1: 58 total_reward:  140
# no of soups made: 2
# avg soup: 1.44
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 282 shaped reward agent 0: 67: shaped reward agent 1: 46 total_reward:  253
# no of soups made: 7
# avg soup: 1.5
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 283 shaped reward agent 0: 42: shaped reward agent 1: 73 total_reward:  195
# no of soups made: 4
# avg soup: 1.54
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 284 shaped reward agent 0: 16: shaped reward agent 1: 25 total_reward:  61
# no of soups made: 1
# avg soup: 1.55
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 285 shaped reward agent 0: 46: shaped reward agent 1: 68 total_reward:  274
# no of soups made: 8
# avg soup: 1.63
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 286 shaped reward agent 0: 76: shaped reward agent 1: 39 total_reward:  275
# no of soups made: 8
# avg soup: 1.71
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 287 shaped reward agent 0: 45: shaped reward agent 1: 85 total_reward:  350
# no of soups made: 11
# avg soup: 1.82
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 288 shaped reward agent 0: 38: shaped reward agent 1: 53 total_reward:  151
# no of soups made: 3
# avg soup: 1.84
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 289 shaped reward agent 0: 43: shaped reward agent 1: 37 total_reward:  140
# no of soups made: 3
# avg soup: 1.86
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 290 shaped reward agent 0: 87: shaped reward agent 1: 45 total_reward:  292
# no of soups made: 8
# avg soup: 1.92
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# ...
# Ep 925 shaped reward agent 0: 114: shaped reward agent 1: 64 total_reward:  558
# no of soups made: 19
# avg soup: 17.22
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 926 shaped reward agent 0: 105: shaped reward agent 1: 58 total_reward:  483
# no of soups made: 16
# avg soup: 17.23
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 927 shaped reward agent 0: 109: shaped reward agent 1: 68 total_reward:  577
# no of soups made: 20
# avg soup: 17.24
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 928 shaped reward agent 0: 65: shaped reward agent 1: 104 total_reward:  549
# no of soups made: 19
# avg soup: 17.23
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 929 shaped reward agent 0: 111: shaped reward agent 1: 65 total_reward:  556
# no of soups made: 19
# avg soup: 17.26
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 930 shaped reward agent 0: 104: shaped reward agent 1: 65 total_reward:  529
# no of soups made: 18
# avg soup: 17.23
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 931 shaped reward agent 0: 69: shaped reward agent 1: 114 total_reward:  583
# no of soups made: 20
# avg soup: 17.23
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 932 shaped reward agent 0: 177: shaped reward agent 1: 69 total_reward:  686
# no of soups made: 22
# avg soup: 17.28
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 933 shaped reward agent 0: 43: shaped reward agent 1: 64 total_reward:  267
# no of soups made: 8
# avg soup: 17.19
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 934 shaped reward agent 0: 109: shaped reward agent 1: 65 total_reward:  554
# no of soups made: 19
# avg soup: 17.21
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 935 shaped reward agent 0: 104: shaped reward agent 1: 62 total_reward:  526
# no of soups made: 18
# avg soup: 17.18
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 936 shaped reward agent 0: 69: shaped reward agent 1: 114 total_reward:  583
# no of soups made: 20
# avg soup: 17.27
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 937 shaped reward agent 0: 66: shaped reward agent 1: 107 total_reward:  593
# no of soups made: 21
# avg soup: 17.3
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 938 shaped reward agent 0: 105: shaped reward agent 1: 64 total_reward:  529
# no of soups made: 18
# avg soup: 17.35
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 939 shaped reward agent 0: 59: shaped reward agent 1: 94 total_reward:  493
# no of soups made: 17
# avg soup: 17.36
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 940 shaped reward agent 0: 58: shaped reward agent 1: 95 total_reward:  493
# no of soups made: 17
# avg soup: 17.31
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 941 shaped reward agent 0: 64: shaped reward agent 1: 105 total_reward:  549
# no of soups made: 19
# avg soup: 17.3
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 942 shaped reward agent 0: 58: shaped reward agent 1: 95 total_reward:  493
# no of soups made: 17
# avg soup: 17.27
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 943 shaped reward agent 0: 67: shaped reward agent 1: 114 total_reward:  561
# no of soups made: 19
# avg soup: 17.28
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 944 shaped reward agent 0: 64: shaped reward agent 1: 105 total_reward:  549
# no of soups made: 19
# avg soup: 17.26
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 945 shaped reward agent 0: 68: shaped reward agent 1: 114 total_reward:  582
# no of soups made: 20
# avg soup: 17.34
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 946 shaped reward agent 0: 45: shaped reward agent 1: 82 total_reward:  387
# no of soups made: 13
# avg soup: 17.33
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 947 shaped reward agent 0: 109: shaped reward agent 1: 68 total_reward:  577
# no of soups made: 20
# avg soup: 17.36
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 948 shaped reward agent 0: 69: shaped reward agent 1: 114 total_reward:  583
# no of soups made: 20
# avg soup: 17.41
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 949 shaped reward agent 0: 109: shaped reward agent 1: 68 total_reward:  577
# no of soups made: 20
# avg soup: 17.45
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 950 shaped reward agent 0: 62: shaped reward agent 1: 106 total_reward:  548
# no of soups made: 19
# avg soup: 17.45
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 951 shaped reward agent 0: 95: shaped reward agent 1: 54 total_reward:  449
# no of soups made: 15
# avg soup: 17.39
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 952 shaped reward agent 0: 11: shaped reward agent 1: 2 total_reward:  13
# no of soups made: 0
# avg soup: 17.27
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 953 shaped reward agent 0: 110: shaped reward agent 1: 65 total_reward:  575
# no of soups made: 20
# avg soup: 17.29
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 954 shaped reward agent 0: 91: shaped reward agent 1: 55 total_reward:  466
# no of soups made: 16
# avg soup: 17.36
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 955 shaped reward agent 0: 109: shaped reward agent 1: 68 total_reward:  577
# no of soups made: 20
# avg soup: 17.35
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 956 shaped reward agent 0: 56: shaped reward agent 1: 100 total_reward:  456
# no of soups made: 15
# avg soup: 17.33
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 957 shaped reward agent 0: 75: shaped reward agent 1: 45 total_reward:  360
# no of soups made: 12
# avg soup: 17.25
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 958 shaped reward agent 0: 47: shaped reward agent 1: 70 total_reward:  317
# no of soups made: 10
# avg soup: 17.17
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 959 shaped reward agent 0: 66: shaped reward agent 1: 104 total_reward:  550
# no of soups made: 19
# avg soup: 17.24
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 960 shaped reward agent 0: 30: shaped reward agent 1: 13 total_reward:  103
# no of soups made: 3
# avg soup: 17.09
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 961 shaped reward agent 0: 64: shaped reward agent 1: 109 total_reward:  533
# no of soups made: 18
# avg soup: 17.07
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 962 shaped reward agent 0: 109: shaped reward agent 1: 63 total_reward:  532
# no of soups made: 18
# avg soup: 17.11
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 963 shaped reward agent 0: 109: shaped reward agent 1: 67 total_reward:  576
# no of soups made: 20
# avg soup: 17.12
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 964 shaped reward agent 0: 100: shaped reward agent 1: 58 total_reward:  498
# no of soups made: 17
# avg soup: 17.17
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 965 shaped reward agent 0: 60: shaped reward agent 1: 104 total_reward:  524
# no of soups made: 18
# avg soup: 17.15
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 966 shaped reward agent 0: 104: shaped reward agent 1: 64 total_reward:  528
# no of soups made: 18
# avg soup: 17.24
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 967 shaped reward agent 0: 61: shaped reward agent 1: 101 total_reward:  502
# no of soups made: 17
# avg soup: 17.25
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 968 shaped reward agent 0: 109: shaped reward agent 1: 61 total_reward:  510
# no of soups made: 17
# avg soup: 17.22
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 969 shaped reward agent 0: 60: shaped reward agent 1: 105 total_reward:  505
# no of soups made: 17
# avg soup: 17.24
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 970 shaped reward agent 0: 114: shaped reward agent 1: 69 total_reward:  563
# no of soups made: 19
# avg soup: 17.36
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 971 shaped reward agent 0: 34: shaped reward agent 1: 68 total_reward:  242
# no of soups made: 7
# avg soup: 17.24
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 972 shaped reward agent 0: 109: shaped reward agent 1: 61 total_reward:  490
# no of soups made: 16
# avg soup: 17.2
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 973 shaped reward agent 0: 109: shaped reward agent 1: 67 total_reward:  556
# no of soups made: 19
# avg soup: 17.23
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 974 shaped reward agent 0: 101: shaped reward agent 1: 64 total_reward:  525
# no of soups made: 18
# avg soup: 17.21
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 975 shaped reward agent 0: 85: shaped reward agent 1: 48 total_reward:  413
# no of soups made: 14
# avg soup: 17.19
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 976 shaped reward agent 0: 56: shaped reward agent 1: 164 total_reward:  520
# no of soups made: 15
# avg soup: 17.14
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 977 shaped reward agent 0: 46: shaped reward agent 1: 130 total_reward:  456
# no of soups made: 14
# avg soup: 17.1
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 978 shaped reward agent 0: 60: shaped reward agent 1: 92 total_reward:  452
# no of soups made: 15
# avg soup: 17.07
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 979 shaped reward agent 0: 114: shaped reward agent 1: 70 total_reward:  564
# no of soups made: 19
# avg soup: 17.09
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 980 shaped reward agent 0: 64: shaped reward agent 1: 109 total_reward:  533
# no of soups made: 18
# avg soup: 17.08
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 981 shaped reward agent 0: 109: shaped reward agent 1: 63 total_reward:  492
# no of soups made: 16
# avg soup: 17.03
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 982 shaped reward agent 0: 57: shaped reward agent 1: 101 total_reward:  478
# no of soups made: 16
# avg soup: 17.03
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 983 shaped reward agent 0: 110: shaped reward agent 1: 65 total_reward:  535
# no of soups made: 18
# avg soup: 17.04
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 984 shaped reward agent 0: 171: shaped reward agent 1: 66 total_reward:  637
# no of soups made: 20
# avg soup: 17.06
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 985 shaped reward agent 0: 90: shaped reward agent 1: 58 total_reward:  468
# no of soups made: 16
# avg soup: 17.02
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 986 shaped reward agent 0: 53: shaped reward agent 1: 84 total_reward:  437
# no of soups made: 15
# avg soup: 16.98
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 987 shaped reward agent 0: 50: shaped reward agent 1: 107 total_reward:  437
# no of soups made: 14
# avg soup: 16.96
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 988 shaped reward agent 0: 109: shaped reward agent 1: 68 total_reward:  577
# no of soups made: 20
# avg soup: 17.0
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 989 shaped reward agent 0: 97: shaped reward agent 1: 60 total_reward:  497
# no of soups made: 17
# avg soup: 16.98
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 990 shaped reward agent 0: 70: shaped reward agent 1: 111 total_reward:  581
# no of soups made: 20
# avg soup: 16.99
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 991 shaped reward agent 0: 70: shaped reward agent 1: 114 total_reward:  604
# no of soups made: 21
# avg soup: 17.04
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 992 shaped reward agent 0: 90: shaped reward agent 1: 56 total_reward:  466
# no of soups made: 16
# avg soup: 16.99
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 993 shaped reward agent 0: 95: shaped reward agent 1: 57 total_reward:  492
# no of soups made: 17
# avg soup: 17.11
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 994 shaped reward agent 0: 72: shaped reward agent 1: 111 total_reward:  603
# no of soups made: 21
# avg soup: 17.15
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 995 shaped reward agent 0: 176: shaped reward agent 1: 66 total_reward:  642
# no of soups made: 20
# avg soup: 17.19
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 996 shaped reward agent 0: 86: shaped reward agent 1: 43 total_reward:  389
# no of soups made: 13
# avg soup: 17.11
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 997 shaped reward agent 0: 67: shaped reward agent 1: 111 total_reward:  578
# no of soups made: 20
# avg soup: 17.13
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 998 shaped reward agent 0: 54: shaped reward agent 1: 94 total_reward:  448
# no of soups made: 15
# avg soup: 17.09
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 999 shaped reward agent 0: 72: shaped reward agent 1: 119 total_reward:  611
# no of soups made: 21
# avg soup: 17.17
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
# Ep 1000 shaped reward agent 0: 64: shaped reward agent 1: 104 total_reward:  528
# no of soups made: 18
# avg soup: 17.16
# eps0:  0.09999000000191018
# eps1:  0.09999000000191018
#
# Example end-of-episode info dump:
#  {'agent_infos': [{}, {}], 'sparse_r_by_agent': [0, 0], 'shaped_r_by_agent': [0, 0], 'phi_s': None, 'phi_s_prime': None, 'episode': {'ep_game_stats': {'tomato_pickup': [[], []], 'useful_tomato_pickup': [[], []], 'tomato_drop': [[], []], 'useful_tomato_drop': [[], []], 'potting_tomato': [[], []], 'onion_pickup': [[6, 27, 31, 45, 53, 59, 66, 70, 74, 81, 88, 93, 101, 107, 111, 116, 122, 129, 136, 140, 144, 149, 156, 161, 167, 174, 178, 187, 198, 210, 214, 219, 227, 234, 239, 246, 251, 257, 263, 268, 274, 280, 284, 288, 293, 304, 309, 315, 319, 324, 332, 337, 347, 355, 359, 364, 370, 380, 385, 391, 395, 399], [5]], 'useful_onion_pickup': [[6, 27, 31, 45, 53, 59, 66, 70, 74, 88, 93, 101, 107, 111, 116, 122, 129, 136, 140, 144, 149, 156, 161, 167, 174, 178, 187, 198, 210, 214, 219, 234, 239, 246, 251, 257, 263, 268, 274, 280, 284, 288, 304, 309, 315, 319, 324, 332, 337, 347, 355, 359, 364, 380, 385, 391, 395, 399], [5]], 'onion_drop': [[], []], 'useful_onion_drop': [[], []], 'potting_onion': [[9, 29, 42, 51, 57, 62, 68, 72, 76, 86, 91, 98, 105, 109, 113, 120, 126, 132, 138, 142, 146, 154, 159, 164, 171, 176, 180, 192, 203, 212, 217, 221, 232, 237, 242, 249, 255, 259, 266, 272, 277, 282, 286, 290, 299, 307, 312, 317, 321, 326, 335, 343, 352, 357, 361, 367, 378, 383, 388, 393, 397], [13]], 'dish_pickup': [[12, 19], [15, 30, 58, 81, 92, 115, 123, 148, 160, 174, 198, 229, 239, 260, 269, 295, 306, 330, 337, 370, 383]], 'useful_dish_pickup': [[12], [15]], 'dish_drop': [[18, 20], [21]], 'useful_dish_drop': [[], []], 'soup_pickup': [[], [43, 66, 85, 98, 119, 135, 153, 167, 187, 201, 231, 242, 264, 280, 298, 311, 333, 349, 375, 388]], 'soup_delivery': [[], [53, 68, 88, 100, 121, 140, 155, 169, 189, 203, 234, 244, 266, 284, 301, 313, 335, 352, 378, 390]], 'soup_drop': [[], []], 'optimal_onion_potting': [[9, 29, 42, 51, 57, 62, 68, 72, 76, 86, 91, 98, 105, 109, 113, 120, 126, 132, 138, 142, 146, 154, 159, 164, 171, 176, 180, 192, 203, 212, 217, 221, 232, 237, 242, 249, 255, 259, 266, 272, 277, 282, 286, 290, 299, 307, 312, 317, 321, 326, 335, 343, 352, 357, 361, 367, 378, 383, 388, 393, 397], [13]], 'optimal_tomato_potting': [[], []], 'viable_onion_potting': [[9, 29, 42, 51, 57, 62, 68, 72, 76, 86, 91, 98, 105, 109, 113, 120, 126, 132, 138, 142, 146, 154, 159, 164, 171, 176, 180, 192, 203, 212, 217, 221, 232, 237, 242, 249, 255, 259, 266, 272, 277, 282, 286, 290, 299, 307, 312, 317, 321, 326, 335, 343, 352, 357, 361, 367, 378, 383, 388, 393, 397], [13]], 'viable_tomato_potting': [[], []], 'catastrophic_onion_potting': [[], []], 'catastrophic_tomato_potting': [[], []], 'useless_onion_potting': [[], []], 'useless_tomato_potting': [[], []], 'cumulative_sparse_rewards_by_agent': array([  0, 360]), 'cumulative_shaped_rewards_by_agent': array([ 64, 104])}, 'ep_sparse_r': 360, 'ep_shaped_r': 168, 'ep_sparse_r_by_agent': array([  0, 360]), 'ep_shaped_r_by_agent': array([ 64, 104]), 'ep_length': 400, 'policy_agent_idx': 0}, 'policy_agent_idx': 0}

# %%
np.savetxt('lay2soup_final.txt', soup_final)
np.savetxt('lay2_soup_SMA100.txt', soup_SMA100)

# %%
counts = []

# Iterate through each episode and agent pair
for episode_index, episode_agents in enumerate(potting_onion):
    episode_count = [0, 0]  # Initialize count for each agent in this episode
    for agent_index, agent_times in enumerate(episode_agents):
        episode_count[agent_index] = len(agent_times)
    counts.append(episode_count)

# Create a filename for the output
output_filename = "lay2_potting_onion.txt"

# Open the file for writing
with open(output_filename, "w") as output_file:
    # Write the header
    output_file.write("Episode\tAgent 1\tAgent 2\n")

    # Write the counts for each episode
    for episode, count in enumerate(counts, start=1):
        agent1_count, agent2_count = count
        output_file.write(f"{episode}\t{agent1_count}\t\t{agent2_count}\n")

print(f"Output saved to {output_filename}")
# Out:
# Output saved to lay2_potting_onion.txt

# %%
agent1_counts = [count[0] for count in counts]
agent2_counts = [count[1] for count in counts]

# Plot the scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(range(1, len(counts) + 1), agent1_counts, label='Agent 1', color='red')
plt.scatter(range(1, len(counts) + 1), agent2_counts, label='Agent 2', color='blue')
plt.xlabel('Episode')
plt.ylabel('Count')
plt.title('Episode-Agent Potting Onion count')
plt.legend()
plt.grid(True)
plt.show()

# %%
counts = []

# Iterate through each episode and agent pair
for episode_index, episode_agents in enumerate(dish_pickup):
    episode_count = [0, 0]  # Initialize count for each agent in this episode
    for agent_index, agent_times in enumerate(episode_agents):
        episode_count[agent_index] = len(agent_times)
    counts.append(episode_count)

# Create a filename for the output
output_filename = "lay2_dish_pickup.txt"

# Open the file for writing
with open(output_filename, "w") as output_file:
    # Write the header
    output_file.write("Episode\tAgent 1\tAgent 2\n")

    # Write the counts for each episode
    for episode, count in enumerate(counts, start=1):
        agent1_count, agent2_count = count
        output_file.write(f"{episode}\t{agent1_count}\t\t{agent2_count}\n")

print(f"Output saved to {output_filename}")
# Out:
# Output saved to lay2_dish_pickup.txt

# %%
agent1_counts = [count[0] for count in counts]
agent2_counts = [count[1] for count in counts]

# Plot the scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(range(1, len(counts) + 1), agent1_counts, label='Agent 1', color='red')
plt.scatter(range(1, len(counts) + 1), agent2_counts, label='Agent 2', color='blue')
plt.xlabel('Episode')
plt.ylabel('Count')
plt.title('Episode-Agent Counts')
plt.legend()
plt.grid(True)
plt.show()

# %%
x1 = [i + 1 for i in range(num_episodes)]
reward_SMA1 = [np.mean(soup_final[max(0, i -100):i+1]) for i in range(num_episodes)]
# plt.plot(x, reward_final, 'o', color ='b', markersize = 3)
plt.scatter(x1, soup_final, color ='b', s=3 )
plt.plot(x1, reward_SMA1, color = 'r', linewidth = 2)
plt.title('number of soups at each episode for layout 2')
plt.xlabel('episode')
plt.ylabel('soups')
# plt.ylim(-500, 500)
plt.grid(True)
plt.savefig('p3.layout2.png')
plt.show()
plt.clf()

# %%
num_play = 100
soup_result_100 = []
dish_pickup = []
potting_onion = []


for e in range(num_play):
  terminal = False
    # The number of soups the agent pair made during the episode
  num_soups_made = 0
    # Reset the environment at the start of each episode
  obs = env.reset()
  total_reward = 0

  while not terminal:
        # set pointer to go back overwrite oldest mem if full

        # Obtain observations for each agent
        if env.agent_idx:
            obs0 = obs["both_agent_obs"][1]
            obs1 = obs["both_agent_obs"][0]
        else:
            obs0 = obs["both_agent_obs"][0]
            obs1 = obs["both_agent_obs"][1]

        # EXPERIENCE/STEP
        a0 = agent0.ChooseAction(obs0)
        a1 = agent1.ChooseAction(obs1)
        if env.agent_idx:
            obs, R, terminal, info = env.step([a1,a0])
        else:
            obs, R, terminal, info = env.step([a0,a1])
        num_soups_made += int(R / 20) # Each served soup generates 20 reward

        soup_final.append(num_soups_made)

  dish_pickup.append(info['episode']['ep_game_stats']['dish_pickup'])
  potting_onion.append(info['episode']['ep_game_stats']['potting_onion'])
  # Display status
  print("Ep {0}".format(e + 1), end=" ")
  print("shaped reward agent 0: {0}:".format(r_0), end=" ")
  print("shaped reward agent 1: {0}".format(r_1), end=" ")
  print("no of soups made: {0}".format(num_soups_made))
  soup_result_100.append(num_soups_made)
# Out:
# Ep 1 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 19
# Ep 2 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 21
# Ep 3 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 12
# Ep 4 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 16
# Ep 5 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 18
# Ep 6 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 18
# Ep 7 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 21
# Ep 8 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 16
# Ep 9 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 19
# Ep 10 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 12
# Ep 11 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 17
# Ep 12 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 18
# Ep 13 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 20
# Ep 14 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 0
# Ep 15 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 15
# Ep 16 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 19
# Ep 17 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 17
# Ep 18 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 18
# Ep 19 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 18
# Ep 20 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 18
# Ep 21 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 20
# Ep 22 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 9
# Ep 23 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 20
# Ep 24 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 15
# Ep 25 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 13
# Ep 26 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 16
# Ep 27 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 16
# Ep 28 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 16
# Ep 29 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 17
# Ep 30 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 17
# Ep 31 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 19
# Ep 32 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 17
# Ep 33 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 19
# Ep 34 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 16
# Ep 35 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 21
# Ep 36 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 17
# Ep 37 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 17
# Ep 38 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 20
# Ep 39 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 16
# Ep 40 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 17
# Ep 41 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 14
# Ep 42 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 20
# Ep 43 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 17
# Ep 44 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 17
# Ep 45 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 17
# Ep 46 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 20
# Ep 47 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 18
# Ep 48 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 15
# Ep 49 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 11
# Ep 50 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 19
# Ep 51 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 18
# Ep 52 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 13
# Ep 53 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 18
# Ep 54 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 16
# Ep 55 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 20
# Ep 56 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 18
# Ep 57 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 19
# Ep 58 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 17
# Ep 59 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 17
# Ep 60 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 16
# Ep 61 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 18
# Ep 62 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 14
# Ep 63 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 17
# Ep 64 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 20
# Ep 65 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 20
# Ep 66 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 10
# Ep 67 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 16
# Ep 68 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 19
# Ep 69 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 21
# Ep 70 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 21
# Ep 71 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 16
# Ep 72 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 15
# Ep 73 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 20
# Ep 74 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 12
# Ep 75 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 19
# Ep 76 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 17
# Ep 77 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 17
# Ep 78 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 19
# Ep 79 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 12
# Ep 80 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 20
# Ep 81 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 21
# Ep 82 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 18
# Ep 83 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 17
# Ep 84 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 0
# Ep 85 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 20
# Ep 86 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 16
# Ep 87 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 5
# Ep 88 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 19
# Ep 89 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 19
# Ep 90 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 21
# Ep 91 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 15
# Ep 92 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 18
# Ep 93 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 14
# Ep 94 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 10
# Ep 95 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 19
# Ep 96 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 16
# Ep 97 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 18
# Ep 98 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 18
# Ep 99 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 12
# Ep 100 shaped reward agent 0: 64: shaped reward agent 1: 104 no of soups made: 17

# %%
x1 = [i + 1 for i in range(num_play)]
# plt.plot(x, reward_final, 'o', color ='b', markersize = 3)
plt.scatter(x1, soup_result_100, color ='b', s=3 )
plt.title('number of soups at each episode for layout 2')
plt.xlabel('episode')
plt.ylabel('soups')
# plt.ylim(-500, 500)
plt.grid(True)
plt.savefig('p3.layout2_test.png')
plt.show()
plt.clf()

# %%
np.savetxt('lay2_soup_result_100.txt',  soup_result_100)
